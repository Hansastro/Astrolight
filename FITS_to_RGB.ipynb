# %% [markdown]
# # How to transform a FITS file to an RGB (debayering)

# %% [markdown]
# The data content in the FITS file is a RAW image. It should be "debayerized". the libary Opencv can be used to do that.

# %%
import cv2
from astropy.io import fits

# %% [markdown]
# First step: Open the file.

# %%
hdulist = fits.open('./Test_Images/Non_Defiltered.fits')

# %%
hdulist[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 5184 / length of data axis 1
# NAXIS2  =                 3456 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# BZERO   =                32768 / offset data range to that of unsigned short
# BSCALE  =                    1 / default scaling factor
# INSTRUME= 'Canon DSLR EOS 1200D' / CCD Name
# TELESCOP= 'Telescope Simulator' / Telescope name
# OBSERVER= 'Unknown '           / Observer name
# OBJECT  = 'Unknown '           / Object name
# EXPTIME =                  0.5 / Total Exposure Time (s)
# PIXSIZE1=                 4.29 / Pixel Size 1 (microns)
# ...
